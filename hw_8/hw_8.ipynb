# %% [markdown]
# ## Проект

# %% [markdown]
# 1. [Загрузка данных](#load_data)
# 2. [Полезные функции](#useful_functions)
# 3. [Подготовка данных](#data_preparation)
# 4. [Построение модели первого уровня](#first_level_model)
# 5. [Генерация признаков для модели второго уровня](#features_engineering)
# 6. [Построение модели второго уровня](#second_level_model)
# 7. [Рекомендации для тестового датасета](#final_recommendations)

# %% [markdown]
# ### 1. Загрузка данных <a class="anchor" id="load_data"></a>

# %% [markdown]
# Загрузим необходимые библиотеки и данные.

# %%
import pandas as pd
import numpy as np

# Для работы с матрицами
from scipy.sparse import csr_matrix

# Матричная факторизация
from implicit import als

from gensim.models import Word2Vec

# Модель второго уровня
from catboost import CatBoostClassifier

import os, sys
sys.path.insert(1, os.getcwd() + '/src/')

from metrics import precision_at_k, recall_at_k
from utils import prefilter_items
from recommenders import MainRecommender

# %%
data = pd.read_csv('webinar_8/course_project/data/retail_train.csv')
item_features = pd.read_csv('webinar_8/course_project/data/product.csv')
user_features = pd.read_csv('webinar_8/course_project/data/hh_demographic.csv')

# %% [markdown]
# ### 2. Полезные функции <a class="anchor" id="useful_functions"></a>

# %% [markdown]
# Опишем функции, которые будут использоваться в дальнейшем.

# %%
def print_stats_data(df_data, name_df):
    print(name_df)
    print(f"Shape: {df_data.shape} Users: {df_data[USER_COL].nunique()} Items: {df_data[ITEM_COL].nunique()}")
    
def make_recommendations(df_result, recommend_model, N_PREDICT=50, USER_COL='user_id'):
    return df_result[USER_COL].apply(lambda x: recommend_model(x, N=N_PREDICT))

def calc_recall(df_data, top_k, ACTUAL_COL='actual'):
    for col_name in df_data.columns[2:]:
        yield col_name, df_data.apply(lambda row: recall_at_k(row[col_name], row[ACTUAL_COL], k=top_k), axis=1).mean()
        
def calc_precision(df_data, top_k, ACTUAL_COL='actual'):
    for col_name in df_data.columns[2:]:
        yield col_name, df_data.apply(lambda row: precision_at_k(row[col_name], row[ACTUAL_COL], k=top_k), axis=1).mean()
        
def rerank(user_id, df, USER_COL='user_id', proba_col_name='proba_item_purchase', N=5):
    return df[df[USER_COL]==user_id].sort_values(proba_col_name, ascending=False).head(N).item_id.tolist()

def get_scores(df_result, recommend_model, N_PREDICT=50, USER_COL='user_id'):
    return df_result[USER_COL].apply(lambda x: recommend_model(x, N=N_PREDICT))

# %% [markdown]
# ### 3. Подготовка данных <a class="anchor" id="data_preparation"></a>

# %% [markdown]
# Проведем переименования определенных признаков и приведем названия к единообразному формату.

# %%
ITEM_COL = 'item_id'
USER_COL = 'user_id'

# column processing
item_features.columns = [col.lower() for col in item_features.columns]
user_features.columns = [col.lower() for col in user_features.columns]

item_features.rename(columns={'product_id': ITEM_COL}, inplace=True)
user_features.rename(columns={'household_key': USER_COL }, inplace=True)

# %% [markdown]
# Разделим выборку на обучающий, валидационный и тестовый датасеты.

# %%
VAL_MATCHER_WEEKS = 5
VAL_RANKER_WEEKS = 3

# берем данные для тренировки matching модели
data_train_matcher = data[data['week_no'] < data['week_no'].max() - (VAL_MATCHER_WEEKS + VAL_RANKER_WEEKS)]

# берем данные для валидации matching модели
data_val_matcher = data[(data['week_no'] >= data['week_no'].max() - (VAL_MATCHER_WEEKS + VAL_RANKER_WEEKS)) &
                      (data['week_no'] < data['week_no'].max() - (VAL_RANKER_WEEKS))]


# берем данные для тренировки ranking модели
data_train_ranker = data_val_matcher.copy()  # Для наглядности. Далее мы добавим изменения, и они будут отличаться

# берем данные для теста ranking, matching модели
data_val_ranker = data[data['week_no'] >= data['week_no'].max() - VAL_RANKER_WEEKS]

# %%
print_stats_data(data_train_matcher,'train_matcher')
print_stats_data(data_val_matcher,'val_matcher')
print_stats_data(data_train_ranker,'train_ranker')
print_stats_data(data_val_ranker,'val_ranker')
# Out:
# train_matcher
# Shape: (2136728, 12) Users: 2498 Items: 84180
# val_matcher
# Shape: (141762, 12) Users: 2097 Items: 25770
# train_ranker
# Shape: (141762, 12) Users: 2097 Items: 25770
# val_ranker
# Shape: (118314, 12) Users: 2042 Items: 24329

# %% [markdown]
# Проведем префильтрацию данных.

# %%
n_items_before = data_train_matcher['item_id'].nunique()

data_train_matcher = prefilter_items(data_train_matcher, item_features=item_features, take_n_popular=10000)

n_items_after = data_train_matcher['item_id'].nunique()
print('Decreased # items from {} to {}'.format(n_items_before, n_items_after))
# Out:
# /Users/rk/Documents/Recommender_systems/L8/src/utils.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['price'] = data['sales_value'] / (np.maximum(data['quantity'], 1))
# Decreased # items from 84180 to 10001

# %% [markdown]
# Оставим только пользователей, которые встречаются в тренировочном датасете, чтобы избежать проблемы холодного старта.

# %%
# ищем общих пользователей
common_users = data_train_matcher.user_id.values

data_val_matcher = data_val_matcher[data_val_matcher.user_id.isin(common_users)]
data_train_ranker = data_train_ranker[data_train_ranker.user_id.isin(common_users)]
data_val_ranker = data_val_ranker[data_val_ranker.user_id.isin(common_users)]

print_stats_data(data_train_matcher,'train_matcher')
print_stats_data(data_val_matcher,'val_matcher')
print_stats_data(data_train_ranker,'train_ranker')
print_stats_data(data_val_ranker,'val_ranker')
# Out:
# train_matcher
# Shape: (872777, 13) Users: 2496 Items: 10001
# val_matcher
# Shape: (141737, 12) Users: 2095 Items: 25768
# train_ranker
# Shape: (141737, 12) Users: 2095 Items: 25768
# val_ranker
# Shape: (118282, 12) Users: 2040 Items: 24325

# %% [markdown]
# ### 4. Построение модели первого уровня <a class="anchor" id="first_level_model"></a>

# %% [markdown]
# Создадим экземляр класса MainRecommender.

# %%
recommender = MainRecommender(data_train_matcher)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/10001 [00:00<?, ?it/s]
#   0%|          | 0/10001 [00:00<?, ?it/s]
#   0%|          | 0/10001 [00:00<?, ?it/s]
#   0%|          | 0/10001 [00:00<?, ?it/s]

# %%
ACTUAL_COL = 'actual'
result_eval_matcher = data_val_matcher.groupby(USER_COL)[ITEM_COL].unique().reset_index()
result_eval_matcher.columns=[USER_COL, ACTUAL_COL]
result_eval_matcher.head(2)
# Out:
#    user_id                                             actual
# 0        1  [1005186, 907466, 909497, 940947, 963542, 1067...
# 1        2  [15830248, 838136, 839656, 861272, 866211, 870...

# %%
N_PREDICT = 100

result_eval_matcher['own_rec'] = make_recommendations(result_eval_matcher, 
                                                      recommender.get_own_recommendations, 
                                                      N_PREDICT=N_PREDICT)

result_eval_matcher['als_rec'] = make_recommendations(result_eval_matcher, 
                                                      recommender.get_als_recommendations, 
                                                      N_PREDICT=N_PREDICT)

result_eval_matcher['bm25_rec'] = make_recommendations(result_eval_matcher, 
                                                      recommender.get_bm25_recommendations, 
                                                      N_PREDICT=N_PREDICT)

result_eval_matcher['tfidf_rec'] = make_recommendations(result_eval_matcher, 
                                                      recommender.get_tfidf_recommendations, 
                                                      N_PREDICT=N_PREDICT)

result_eval_matcher['cosine_rec'] = make_recommendations(result_eval_matcher, 
                                                      recommender.get_cosine_recommendations, 
                                                      N_PREDICT=N_PREDICT)

# %%
result_eval_matcher.head(2)
# Out:
#    user_id                                             actual  \
# 0        1  [1005186, 907466, 909497, 940947, 963542, 1067...
# 1        2  [15830248, 838136, 839656, 861272, 866211, 870...
#
#                                              own_rec  \
# 0  [940947, 856942, 10149640, 865456, 1004906, 55...
# 1  [8090521, 1075368, 1040807, 5569230, 940947, 1...
#
#                                              als_rec  \
# 0  [1029743, 878285, 865456, 871570, 1006184, 872...
# 1  [930118, 5569845, 5569230, 1106523, 12301109, ...
#
#                                             bm25_rec  \
# 0  [1127831, 940947, 916122, 844179, 1004906, 878...
# 1  [1044078, 844179, 5569230, 916122, 8090521, 11...
#
#                                            tfidf_rec  \
# 0  [916122, 1127831, 844179, 866211, 1029743, 102...
# 1  [916122, 844179, 1029743, 1004906, 1044078, 55...
#
#                                           cosine_rec
# 0  [6391068, 877391, 9297615, 5577022, 5582712, 9...
# 1  [8090521, 1103898, 978332, 1076580, 911974, 10...

# %%
TOPK_RECALL = 100
sorted(calc_recall(result_eval_matcher, TOPK_RECALL), key=lambda x: x[1],reverse=True)
# Out:
# [('own_rec', 0.1277189626164173),
#  ('tfidf_rec', 0.12683248535219407),
#  ('als_rec', 0.12391194179926528),
#  ('cosine_rec', 0.12390732213587671),
#  ('bm25_rec', 0.11469747149566534)]

# %% [markdown]
# Как видим лучшие результаты показывает модель на основе предыдущих покупок пользователя.

# %% [markdown]
# ### 5. Генерация признаков для модели второго уровня <a class="anchor" id="features_engineering"></a>

# %% [markdown]
# Cформируем датасет для построения модели ранжирования, сгенерируем новые признаки и построим модель, которая будет работать с отобранными товарами для построения окончательных рекомендаций.

# %%
# взяли пользователей из трейна для ранжирования

df_match_candidates = pd.DataFrame(data_train_ranker[USER_COL].unique())
df_match_candidates.columns = [USER_COL]

df_match_candidates['candidates'] = make_recommendations(df_match_candidates, 
                                                         recommender.get_own_recommendations, 
                                                         N_PREDICT=N_PREDICT)

df_match_candidates['candidates_scores'] = get_scores(df_match_candidates, 
                                                      recommender.get_own_scores, 
                                                      N_PREDICT=N_PREDICT)

df_items = df_match_candidates.apply(lambda x: pd.Series(x['candidates']), axis=1).stack().\
            reset_index(level=1, drop=True)
df_scores = df_match_candidates.apply(lambda x: pd.Series(x['candidates_scores']), axis=1).stack().\
            reset_index(level=1, drop=True)
df_items.name = 'item_id'
df_match_candidates = df_match_candidates.drop(['candidates', 'candidates_scores'], axis=1).join(df_items)

df_match_candidates['item_score'] = df_scores

df_match_candidates.head()
# Out:
#    user_id  item_id    item_score
# 0     1827   907631  57976.974666
# 0     1827   940947  42612.148521
# 0     1827  5568378  40380.408152
# 0     1827   854405  39497.493468
# 0     1827  1029743  28444.228691

# %%
df_ranker_train = data_train_ranker[[USER_COL, ITEM_COL]].copy()
df_ranker_train['target'] = 1  # тут только покупки 

df_ranker_train = df_match_candidates.merge(df_ranker_train, on=[USER_COL, ITEM_COL], how='left')

# чистим дубликаты
df_ranker_train = df_ranker_train.drop_duplicates(subset=[USER_COL, ITEM_COL])

df_ranker_train['target'].fillna(0, inplace= True)

df_ranker_train.head()
# Out:
#    user_id  item_id    item_score  target
# 0     1827   907631  57976.974666     0.0
# 1     1827   940947  42612.148521     0.0
# 2     1827  5568378  40380.408152     0.0
# 3     1827   854405  39497.493468     0.0
# 4     1827  1029743  28444.228691     1.0

# %%
df_ranker_train.target.value_counts()
# Out:
# 0.0    192109
# 1.0     14645
# Name: target, dtype: int64

# %%
df_ranker_train = df_ranker_train.merge(item_features, on='item_id', how='left')
df_ranker_train = df_ranker_train.merge(user_features, on='user_id', how='left')

df_ranker_train.head(2)
# Out:
#    user_id  item_id    item_score  target  manufacturer  department     brand  \
# 0     1827   907631  57976.974666     0.0          1039     GROCERY  National
# 1     1827   940947  42612.148521     0.0          2082  MEAT-PCKGD  National
#
#   commodity_desc sub_commodity_desc curr_size_of_product age_desc  \
# 0   FROZEN PIZZA  SNACKS/APPETIZERS                           NaN
# 1     HEAT/SERVE            ENTREES                24 OZ      NaN
#
#   marital_status_code income_desc homeowner_desc hh_comp_desc  \
# 0                 NaN         NaN            NaN          NaN
# 1                 NaN         NaN            NaN          NaN
#
#   household_size_desc kid_category_desc
# 0                 NaN               NaN
# 1                 NaN               NaN

# %% [markdown]
# Сгенерируем новые признаки и добавим их к датасету для обучения.

# %%
# Добавим параметр категории к исходному обучающему датасету для удобства создания новых фичей
data_department = data_train_ranker.merge(item_features[['item_id', 'department']], on='item_id', how='inner')
data_department.head(2)
# Out:
#    user_id    basket_id  day  item_id  quantity  sales_value  store_id  \
# 0     1827  40702967646  601   891141         2         2.73     33923
# 1      496  40739402373  603   891141         1         1.83       445
#
#    retail_disc  trans_time  week_no  coupon_disc  coupon_match_disc department
# 0          0.0           7       87          0.0                0.0    PRODUCE
# 1          0.0        2226       87          0.0                0.0    PRODUCE

# %%
# Средная цена купленных товаров пользователем
users_sales = data_train_ranker.groupby(USER_COL)[['sales_value', 'quantity']].sum().reset_index()
users_sales['avg_price'] = users_sales['sales_value'] / users_sales['quantity']
df_ranker_train = df_ranker_train.merge(users_sales[['user_id', 'avg_price']], on='user_id', how='left')
df_ranker_train.head(2)
# Out:
#    user_id  item_id    item_score  target  manufacturer  department     brand  \
# 0     1827   907631  57976.974666     0.0          1039     GROCERY  National
# 1     1827   940947  42612.148521     0.0          2082  MEAT-PCKGD  National
#
#   commodity_desc sub_commodity_desc curr_size_of_product age_desc  \
# 0   FROZEN PIZZA  SNACKS/APPETIZERS                           NaN
# 1     HEAT/SERVE            ENTREES                24 OZ      NaN
#
#   marital_status_code income_desc homeowner_desc hh_comp_desc  \
# 0                 NaN         NaN            NaN          NaN
# 1                 NaN         NaN            NaN          NaN
#
#   household_size_desc kid_category_desc  avg_price
# 0                 NaN               NaN   2.208947
# 1                 NaN               NaN   2.208947

# %%
# Количество покупок в каждой категории и средная сумма покупки в каждой категории для пользователя
users_sales_department = data_department.groupby([USER_COL, 'department'])\
                        [['sales_value', 'quantity']].sum().reset_index()
users_sales_department.rename(columns={'quantity': 'n_sold_category'}, inplace=True)
users_sales_department['avg_transaction_category'] = users_sales_department['sales_value']\
                                                    /users_sales_department['n_sold_category']
users_sales_department.drop(columns=['sales_value'], inplace=True)

df_ranker_train = df_ranker_train.merge(
    users_sales_department, on=[USER_COL, 'department'], how='left')
df_ranker_train['Missing n_sold_category'] = 0
df_ranker_train.loc[df_ranker_train['n_sold_category'].isna(), 'Missing n_sold_category'] = 1
df_ranker_train['n_sold_category'].fillna(0, inplace=True)

df_ranker_train.head(2)
# Out:
#    user_id  item_id    item_score  target  manufacturer  department     brand  \
# 0     1827   907631  57976.974666     0.0          1039     GROCERY  National
# 1     1827   940947  42612.148521     0.0          2082  MEAT-PCKGD  National
#
#   commodity_desc sub_commodity_desc curr_size_of_product  ...  \
# 0   FROZEN PIZZA  SNACKS/APPETIZERS                       ...
# 1     HEAT/SERVE            ENTREES                24 OZ  ...
#
#   marital_status_code income_desc homeowner_desc hh_comp_desc  \
# 0                 NaN         NaN            NaN          NaN
# 1                 NaN         NaN            NaN          NaN
#
#   household_size_desc kid_category_desc avg_price  n_sold_category  \
# 0                 NaN               NaN  2.208947             25.0
# 1                 NaN               NaN  2.208947              2.0
#
#    avg_transaction_category  Missing n_sold_category
# 0                    2.2408                        0
# 1                    1.4900                        0
#
# [2 rows x 21 columns]

# %%
# Средняя сумма покупки в категории
department_sales = data_department.groupby('department')['sales_value'].mean().reset_index()
department_sales.rename(columns={'sales_value': 'mean_sales_value_category'}, inplace=True)
department_sales.tail(2)

n_weeks = data_department['week_no'].max() - data_department['week_no'].min() + 1

# Количество покупок юзером конкретной категории в неделю
users_department = data_department.groupby([USER_COL, 'department'])['quantity'].sum().reset_index()
users_department['quantity'] /= n_weeks
users_department.rename(columns={'quantity': 'n_sold_category_user_week'}, inplace=True)

df_ranker_train = df_ranker_train.merge(department_sales, on='department', how='left')
df_ranker_train = df_ranker_train.merge(users_department, on=[USER_COL, 'department'], how='left')
df_ranker_train.head(2)
# Out:
#    user_id  item_id    item_score  target  manufacturer  department     brand  \
# 0     1827   907631  57976.974666     0.0          1039     GROCERY  National
# 1     1827   940947  42612.148521     0.0          2082  MEAT-PCKGD  National
#
#   commodity_desc sub_commodity_desc curr_size_of_product  ... homeowner_desc  \
# 0   FROZEN PIZZA  SNACKS/APPETIZERS                       ...            NaN
# 1     HEAT/SERVE            ENTREES                24 OZ  ...            NaN
#
#   hh_comp_desc household_size_desc kid_category_desc avg_price  \
# 0          NaN                 NaN               NaN  2.208947
# 1          NaN                 NaN               NaN  2.208947
#
#   n_sold_category avg_transaction_category  Missing n_sold_category  \
# 0            25.0                   2.2408                        0
# 1             2.0                   1.4900                        0
#
#    mean_sales_value_category  n_sold_category_user_week
# 0                   2.541433                        5.0
# 1                   3.828210                        0.4
#
# [2 rows x 23 columns]

# %%
# Цена
items_sales = data_department.groupby(ITEM_COL)[['sales_value', 'quantity']].sum().reset_index()
items_sales['price'] = items_sales['sales_value'] / items_sales['quantity']
items_sales['price'].fillna(0, inplace=True)

# Количество покупок товара в неделю
items_sales['quantity_per_week'] = items_sales['quantity'] / n_weeks


df_ranker_train = df_ranker_train.merge(items_sales[[ITEM_COL,'price', 'quantity_per_week']],
                                        on=ITEM_COL, how='left')

df_ranker_train['Missing price'] = 0
df_ranker_train.loc[df_ranker_train['price'].isna(), 'Missing price'] = 1
df_ranker_train['price'].fillna(0, inplace=True)

df_ranker_train['Missing quantity per week'] = 0
df_ranker_train.loc[df_ranker_train['quantity_per_week'].isna(), 'Missing quantity per week'] = 1
df_ranker_train['quantity_per_week'].fillna(0, inplace=True)

df_ranker_train.head()
# Out:
#    user_id  item_id    item_score  target  manufacturer  department     brand  \
# 0     1827   907631  57976.974666     0.0          1039     GROCERY  National
# 1     1827   940947  42612.148521     0.0          2082  MEAT-PCKGD  National
# 2     1827  5568378  40380.408152     0.0           544     GROCERY  National
# 3     1827   854405  39497.493468     0.0           397  MEAT-PCKGD  National
# 4     1827  1029743  28444.228691     1.0            69     GROCERY   Private
#
#         commodity_desc      sub_commodity_desc curr_size_of_product  ...  \
# 0         FROZEN PIZZA       SNACKS/APPETIZERS                       ...
# 1           HEAT/SERVE                 ENTREES                24 OZ  ...
# 2           BAG SNACKS    TORTILLA/NACHO CHIPS              12.5 OZ  ...
# 3          MEAT - MISC  BREAST - BONELESS(IQF)                40 OZ  ...
# 4  FLUID MILK PRODUCTS   FLUID MILK WHITE ONLY                 1 GA  ...
#
#   avg_price n_sold_category avg_transaction_category Missing n_sold_category  \
# 0  2.208947            25.0                   2.2408                       0
# 1  2.208947             2.0                   1.4900                       0
# 2  2.208947            25.0                   2.2408                       0
# 3  2.208947             2.0                   1.4900                       0
# 4  2.208947            25.0                   2.2408                       0
#
#   mean_sales_value_category n_sold_category_user_week     price  \
# 0                  2.541433                       5.0  2.985366
# 1                  3.828210                       0.4  2.650096
# 2                  2.541433                       5.0  2.381258
# 3                  3.828210                       0.4  6.779474
# 4                  2.541433                       5.0  2.424173
#
#    quantity_per_week  Missing price  Missing quantity per week
# 0               16.4              0                          0
# 1               20.8              0                          0
# 2               30.2              0                          0
# 3               11.4              0                          0
# 4              198.4              0                          0
#
# [5 rows x 27 columns]

# %%
# Количество уникальных магазинов, в которых продавался товар
items_stores = data_department.groupby(ITEM_COL)['store_id'].nunique().reset_index()
items_stores.rename(columns={'store_id': 'n_unique_stores'}, inplace=True)
df_ranker_train = df_ranker_train.merge(items_stores, on=ITEM_COL, how='left')

df_ranker_train.head(2)
# Out:
#    user_id  item_id    item_score  target  manufacturer  department     brand  \
# 0     1827   907631  57976.974666     0.0          1039     GROCERY  National
# 1     1827   940947  42612.148521     0.0          2082  MEAT-PCKGD  National
#
#   commodity_desc sub_commodity_desc curr_size_of_product  ... n_sold_category  \
# 0   FROZEN PIZZA  SNACKS/APPETIZERS                       ...            25.0
# 1     HEAT/SERVE            ENTREES                24 OZ  ...             2.0
#
#   avg_transaction_category Missing n_sold_category mean_sales_value_category  \
# 0                   2.2408                       0                  2.541433
# 1                   1.4900                       0                  3.828210
#
#   n_sold_category_user_week     price quantity_per_week  Missing price  \
# 0                       5.0  2.985366              16.4              0
# 1                       0.4  2.650096              20.8              0
#
#    Missing quantity per week  n_unique_stores
# 0                          0             41.0
# 1                          0             49.0
#
# [2 rows x 28 columns]

# %%
# Среднее количество транзакций клиента в неделю
users_transactions = data_department.groupby(USER_COL)[ITEM_COL].count().reset_index()
users_transactions.rename(columns={'item_id': 'n_transactions_per_week'}, inplace=True)
users_transactions['n_transactions_per_week'] /= n_weeks


df_ranker_train = df_ranker_train.merge(users_transactions, on=USER_COL, how='left')

df_ranker_train.tail(2)
# Out:
#         user_id  item_id   item_score  target  manufacturer     department  \
# 206752     1745   841443  3106.164464     0.0          1087  SEAFOOD-PCKGD
# 206753     1745   949120  3083.968051     0.0          1318        GROCERY
#
#            brand          commodity_desc     sub_commodity_desc  \
# 206752  National        SEAFOOD - FROZEN  FRZN BRD STICK/PORTON
# 206753  National  PICKLE/RELISH/PKLD VEG                PICKLES
#
#        curr_size_of_product  ... avg_transaction_category  \
# 206752              24.5 OZ  ...                      NaN
# 206753                24 OZ  ...                 2.663333
#
#        Missing n_sold_category mean_sales_value_category  \
# 206752                       1                  5.810053
# 206753                       0                  2.541433
#
#        n_sold_category_user_week price quantity_per_week Missing price  \
# 206752                       NaN   0.0               0.0             1
# 206753                       0.6   0.0               0.0             1
#
#         Missing quantity per week  n_unique_stores  n_transactions_per_week
# 206752                          1              NaN                      0.6
# 206753                          1              NaN                      0.6
#
# [2 rows x 29 columns]

# %%
# Средний чек
users_sales = data_train_ranker.groupby(USER_COL)['sales_value'].mean().reset_index()
users_sales.rename(columns={'sales_value': 'avg_cheque'}, inplace=True)
df_ranker_train = df_ranker_train.merge(users_sales[['user_id', 'avg_cheque']], on='user_id', how='left')
df_ranker_train.head(2)
# Out:
#    user_id  item_id    item_score  target  manufacturer  department     brand  \
# 0     1827   907631  57976.974666     0.0          1039     GROCERY  National
# 1     1827   940947  42612.148521     0.0          2082  MEAT-PCKGD  National
#
#   commodity_desc sub_commodity_desc curr_size_of_product  ...  \
# 0   FROZEN PIZZA  SNACKS/APPETIZERS                       ...
# 1     HEAT/SERVE            ENTREES                24 OZ  ...
#
#   Missing n_sold_category mean_sales_value_category n_sold_category_user_week  \
# 0                       0                  2.541433                       5.0
# 1                       0                  3.828210                       0.4
#
#       price quantity_per_week Missing price Missing quantity per week  \
# 0  2.985366              16.4             0                         0
# 1  2.650096              20.8             0                         0
#
#    n_unique_stores  n_transactions_per_week  avg_cheque
# 0             41.0                      6.0       2.798
# 1             49.0                      6.0       2.798
#
# [2 rows x 30 columns]

# %%
# Среднее количество уникальных категорий в корзине
users_baskets = data_department.groupby([USER_COL, 'basket_id'])['department'].nunique().reset_index()
users_baskets = users_baskets.groupby(USER_COL)['department'].mean().reset_index()
users_baskets.rename(columns={'department': 'avg_basket_department'}, inplace=True)
df_ranker_train = df_ranker_train.merge(users_baskets[['user_id', 'avg_basket_department']], on='user_id', how='left')
df_ranker_train.head(2)
# Out:
#    user_id  item_id    item_score  target  manufacturer  department     brand  \
# 0     1827   907631  57976.974666     0.0          1039     GROCERY  National
# 1     1827   940947  42612.148521     0.0          2082  MEAT-PCKGD  National
#
#   commodity_desc sub_commodity_desc curr_size_of_product  ...  \
# 0   FROZEN PIZZA  SNACKS/APPETIZERS                       ...
# 1     HEAT/SERVE            ENTREES                24 OZ  ...
#
#   mean_sales_value_category n_sold_category_user_week     price  \
# 0                  2.541433                       5.0  2.985366
# 1                  3.828210                       0.4  2.650096
#
#   quantity_per_week Missing price Missing quantity per week n_unique_stores  \
# 0              16.4             0                         0            41.0
# 1              20.8             0                         0            49.0
#
#    n_transactions_per_week  avg_cheque  avg_basket_department
# 0                      6.0       2.798                    2.4
# 1                      6.0       2.798                    2.4
#
# [2 rows x 31 columns]

# %% [markdown]
# Построим признак, отражающий средний интервал между покупками пользователя.

# %%
users_days = data_department.groupby(USER_COL)['day'].unique().reset_index()
users_days['day'] = users_days['day'].apply(lambda x: sorted(x))
users_days.head()
# Out:
#    user_id                                                day
# 0        1                     [606, 608, 610, 620, 622, 632]
# 1        2                               [608, 614, 620, 622]
# 2        4                                    [605, 617, 627]
# 3        6  [603, 607, 610, 611, 616, 619, 620, 624, 627, ...
# 4        7                          [606, 610, 614, 623, 629]

# %%
def avg_ndays(days):
    diff = 0
    if len(days) > 1:
        for i in range(len(days) - 1):
            diff += days[i+1] - days[i]
        return diff / (len(days) - 1)
    else:
        return 0
    
users_days['avg_interval'] = users_days['day'].apply(avg_ndays)

df_ranker_train = df_ranker_train.merge(users_days[['user_id', 'avg_interval']], on='user_id', how='left')
df_ranker_train.head(2)
# Out:
#    user_id  item_id    item_score  target  manufacturer  department     brand  \
# 0     1827   907631  57976.974666     0.0          1039     GROCERY  National
# 1     1827   940947  42612.148521     0.0          2082  MEAT-PCKGD  National
#
#   commodity_desc sub_commodity_desc curr_size_of_product  ...  \
# 0   FROZEN PIZZA  SNACKS/APPETIZERS                       ...
# 1     HEAT/SERVE            ENTREES                24 OZ  ...
#
#   n_sold_category_user_week     price quantity_per_week Missing price  \
# 0                       5.0  2.985366              16.4             0
# 1                       0.4  2.650096              20.8             0
#
#   Missing quantity per week n_unique_stores n_transactions_per_week  \
# 0                         0            41.0                     6.0
# 1                         0            49.0                     6.0
#
#    avg_cheque  avg_basket_department  avg_interval
# 0       2.798                    2.4           7.0
# 1       2.798                    2.4           7.0
#
# [2 rows x 32 columns]

# %% [markdown]
# Построим признак, в котором будет закодировано место товара в пяти последних покупках клиента.

# %%
users_items = data_train_ranker.groupby(USER_COL)[ITEM_COL].apply(list).reset_index()
users_items['item_id'] = users_items['item_id'].apply(lambda x: x[-5:])
users_items.head()
# Out:
#    user_id                                            item_id
# 0        1     [5577022, 8293439, 9526676, 9527558, 10149640]
# 1        2  [7407562, 10149597, 13776981, 15572067, 17215077]
# 2        4       [963365, 1038692, 1133312, 5570830, 7431408]
# 3        6       [1099058, 895268, 1017061, 1082185, 1119051]
# 4        7  [9837501, 12524016, 13072715, 13987153, 13987338]

# %%
def code_last_sales(x, df=users_items):
    last_sales = df.loc[df['user_id'] == x[0], 'item_id'].item()
    code = str()
    last_sales.reverse()
    for item in last_sales:
        code += '1' if item == x[1] else '0'
    return code

df_ranker_train['Last5sales'] = df_ranker_train[[USER_COL, ITEM_COL]].apply(code_last_sales, axis=1)
df_ranker_train.head(2)
# Out:
#    user_id  item_id    item_score  target  manufacturer  department     brand  \
# 0     1827   907631  57976.974666     0.0          1039     GROCERY  National
# 1     1827   940947  42612.148521     0.0          2082  MEAT-PCKGD  National
#
#   commodity_desc sub_commodity_desc curr_size_of_product  ...     price  \
# 0   FROZEN PIZZA  SNACKS/APPETIZERS                       ...  2.985366
# 1     HEAT/SERVE            ENTREES                24 OZ  ...  2.650096
#
#   quantity_per_week Missing price Missing quantity per week n_unique_stores  \
# 0              16.4             0                         0            41.0
# 1              20.8             0                         0            49.0
#
#   n_transactions_per_week avg_cheque  avg_basket_department  avg_interval  \
# 0                     6.0      2.798                    2.4           7.0
# 1                     6.0      2.798                    2.4           7.0
#
#    Last5sales
# 0       00000
# 1       00000
#
# [2 rows x 33 columns]

# %% [markdown]
# Построим модель Word2Vec для получения эмбеддингов товаров, а затем посчитаем длину вектора, описывающего каждый товар, и расстояние от word2vec эмбеддинга товара до среднего эмбеддинга товаров, купленных юзером.

# %%
df_ = data_train_ranker.groupby(USER_COL)[ITEM_COL].unique().reset_index()
df_.head()
# Out:
#    user_id                                            item_id
# 0        1  [1005186, 907466, 909497, 940947, 963542, 1067...
# 1        2  [15830248, 838136, 839656, 861272, 866211, 870...
# 2        4  [883932, 970760, 1035676, 1055863, 1097610, 67...
# 3        6  [873654, 994928, 1098844, 1122879, 8357613, 98...
# 4        7  [836281, 843306, 845294, 914190, 920456, 93886...

# %%
purchases = []

for user in df_['user_id']:
    purchases.append([str(item) for item in df_[df_['user_id'] == user].item_id.values[0]])
    
print(f"Total # of Sessions: {len(purchases)}")
# Out:
# Total # of Sessions: 2095

# %%
w2v_model = Word2Vec(min_count=1, vector_size=100, sg=1, workers=3)
w2v_model.build_vocab(purchases, progress_per=100)
w2v_model.train(purchases, total_examples=w2v_model.corpus_count, epochs=10, report_delay=1)
# Out:
# (1209222, 1214930)

# %%
def word2vec_len(itemid):
    try:
        return sum([i**2 for i in w2v_model.wv[str(itemid)]])
    except:
        return -1

df_ranker_train['Word2Vec_length'] = df_ranker_train[ITEM_COL].apply(lambda x: word2vec_len(x))
df_ranker_train.head(2)
# Out:
#    user_id  item_id    item_score  target  manufacturer  department     brand  \
# 0     1827   907631  57976.974666     0.0          1039     GROCERY  National
# 1     1827   940947  42612.148521     0.0          2082  MEAT-PCKGD  National
#
#   commodity_desc sub_commodity_desc curr_size_of_product  ...  \
# 0   FROZEN PIZZA  SNACKS/APPETIZERS                       ...
# 1     HEAT/SERVE            ENTREES                24 OZ  ...
#
#   quantity_per_week Missing price Missing quantity per week n_unique_stores  \
# 0              16.4             0                         0            41.0
# 1              20.8             0                         0            49.0
#
#   n_transactions_per_week avg_cheque avg_basket_department  avg_interval  \
# 0                     6.0      2.798                   2.4           7.0
# 1                     6.0      2.798                   2.4           7.0
#
#    Last5sales  Word2Vec_length
# 0       00000         7.754568
# 1       00000         5.292544
#
# [2 rows x 34 columns]

# %%
def avg_word2vec(items):
    return sum([w2v_model.wv[str(item)] for item in items]) / len(items)

df_['Avg_Word2Vec'] = df_[ITEM_COL].apply(avg_word2vec)
df_.head()
# Out:
#    user_id                                            item_id  \
# 0        1  [1005186, 907466, 909497, 940947, 963542, 1067...
# 1        2  [15830248, 838136, 839656, 861272, 866211, 870...
# 2        4  [883932, 970760, 1035676, 1055863, 1097610, 67...
# 3        6  [873654, 994928, 1098844, 1122879, 8357613, 98...
# 4        7  [836281, 843306, 845294, 914190, 920456, 93886...
#
#                                         Avg_Word2Vec
# 0  [-0.101323694, 0.18119045, 0.20122087, 0.02709...
# 1  [-0.089792326, 0.2482764, 0.19895303, 0.067954...
# 2  [-0.09244502, 0.22552814, 0.20331387, 0.038374...
# 3  [-0.084583975, 0.22696072, 0.1969174, 0.045245...
# 4  [-0.09863084, 0.21351701, 0.21236424, 0.027541...

# %%
def get_w2v_distance(x, df=df_):
    avg_w2v = df.loc[df_[USER_COL] == x[0], 'Avg_Word2Vec'].item()
    try:
        return sum((w2v_model.wv[str(x[1])] - avg_w2v) ** 2)
    except:
        return -1
    
df_ranker_train['Word2Vec_distance_from_avg'] = df_ranker_train[[USER_COL, ITEM_COL]].\
                                                apply(get_w2v_distance, axis=1)
df_ranker_train.head(2)
# Out:
#    user_id  item_id    item_score  target  manufacturer  department     brand  \
# 0     1827   907631  57976.974666     0.0          1039     GROCERY  National
# 1     1827   940947  42612.148521     0.0          2082  MEAT-PCKGD  National
#
#   commodity_desc sub_commodity_desc curr_size_of_product  ... Missing price  \
# 0   FROZEN PIZZA  SNACKS/APPETIZERS                       ...             0
# 1     HEAT/SERVE            ENTREES                24 OZ  ...             0
#
#   Missing quantity per week n_unique_stores n_transactions_per_week  \
# 0                         0            41.0                     6.0
# 1                         0            49.0                     6.0
#
#   avg_cheque avg_basket_department avg_interval  Last5sales  Word2Vec_length  \
# 0      2.798                   2.4          7.0       00000         7.754568
# 1      2.798                   2.4          7.0       00000         5.292544
#
#    Word2Vec_distance_from_avg
# 0                    3.749243
# 1                    1.855993
#
# [2 rows x 35 columns]

# %% [markdown]
# ### 6. Построение модели второго уровня <a class="anchor" id="second_level_model"></a>

# %% [markdown]
# Теперь обучим модель ранжирования и посчитаем метрики.

# %%
X_train = df_ranker_train.drop(['target', 
                                'Missing n_sold_category', 
                                'n_sold_category_user_week', 
                                'mean_sales_value_category',], axis=1)
y_train = df_ranker_train['target']

# %%
cat_feats = ['manufacturer', 
             'department', 
             'brand', 
             'commodity_desc',
             'sub_commodity_desc',
             'curr_size_of_product',
             'age_desc',
             'marital_status_code',
             'income_desc',
             'homeowner_desc',
             'hh_comp_desc',
             'household_size_desc',
             'kid_category_desc',
             'Missing price',
             'Missing quantity per week',
             'Last5sales',
            ]


for column in cat_feats:
    X_train[column].fillna(0, inplace=True)
    
X_train[cat_feats] = X_train[cat_feats].astype('category')

# %%
# %%time
cb = CatBoostClassifier(learning_rate=0.1,
                        max_depth=12,
                        n_estimators=500,
                        random_state=42, 
                        cat_features=cat_feats, 
                        silent=False)

cb.fit(X_train, y_train)

train_preds = cb.predict_proba(X_train)
# Out:
# Custom logger is already specified. Specify more than one logger at same time is not thread safe.
# 0:	learn: 0.5463991	total: 668ms	remaining: 5m 33s
# 1:	learn: 0.4593857	total: 921ms	remaining: 3m 49s
# 2:	learn: 0.3922666	total: 1.6s	remaining: 4m 25s
# 3:	learn: 0.3465231	total: 2.31s	remaining: 4m 46s
# 4:	learn: 0.3138859	total: 2.61s	remaining: 4m 18s
# 5:	learn: 0.2792883	total: 3.69s	remaining: 5m 3s
# 6:	learn: 0.2533568	total: 4.75s	remaining: 5m 34s
# 7:	learn: 0.2368378	total: 5.37s	remaining: 5m 30s
# 8:	learn: 0.2254653	total: 6.37s	remaining: 5m 47s
# 9:	learn: 0.2155984	total: 7.3s	remaining: 5m 57s
# 10:	learn: 0.2080455	total: 8.16s	remaining: 6m 2s
# 11:	learn: 0.2024231	total: 9.12s	remaining: 6m 10s
# 12:	learn: 0.1988072	total: 10.2s	remaining: 6m 20s
# 13:	learn: 0.1947724	total: 11.1s	remaining: 6m 26s
# 14:	learn: 0.1932724	total: 11.2s	remaining: 6m 3s
# 15:	learn: 0.1902265	total: 12.1s	remaining: 6m 4s
# 16:	learn: 0.1884176	total: 13s	remaining: 6m 9s
# 17:	learn: 0.1866174	total: 14s	remaining: 6m 15s
# 18:	learn: 0.1852144	total: 14.9s	remaining: 6m 16s
# 19:	learn: 0.1847484	total: 15s	remaining: 6m 1s
# 20:	learn: 0.1837194	total: 16s	remaining: 6m 5s
# 21:	learn: 0.1821813	total: 17s	remaining: 6m 8s
# 22:	learn: 0.1809691	total: 17.9s	remaining: 6m 12s
# 23:	learn: 0.1797904	total: 19s	remaining: 6m 16s
# 24:	learn: 0.1786322	total: 20.1s	remaining: 6m 22s
# 25:	learn: 0.1774550	total: 21s	remaining: 6m 22s
# 26:	learn: 0.1765369	total: 22.1s	remaining: 6m 26s
# 27:	learn: 0.1754434	total: 23.5s	remaining: 6m 36s
# 28:	learn: 0.1743172	total: 24.5s	remaining: 6m 37s
# 29:	learn: 0.1733612	total: 25.5s	remaining: 6m 39s
# 30:	learn: 0.1727313	total: 26.5s	remaining: 6m 41s
# 31:	learn: 0.1718006	total: 27.6s	remaining: 6m 43s
# 32:	learn: 0.1713265	total: 28.7s	remaining: 6m 45s
# 33:	learn: 0.1706696	total: 29.7s	remaining: 6m 46s
# 34:	learn: 0.1698785	total: 30.6s	remaining: 6m 46s
# 35:	learn: 0.1695269	total: 31.6s	remaining: 6m 46s
# 36:	learn: 0.1690461	total: 32.5s	remaining: 6m 46s
# 37:	learn: 0.1683899	total: 33.5s	remaining: 6m 47s
# 38:	learn: 0.1677259	total: 34.4s	remaining: 6m 46s
# 39:	learn: 0.1672760	total: 35.3s	remaining: 6m 46s
# 40:	learn: 0.1666556	total: 36.4s	remaining: 6m 47s
# 41:	learn: 0.1665042	total: 37.3s	remaining: 6m 47s
# 42:	learn: 0.1659814	total: 38.5s	remaining: 6m 48s
# 43:	learn: 0.1656088	total: 39.3s	remaining: 6m 47s
# 44:	learn: 0.1650632	total: 40.3s	remaining: 6m 47s
# 45:	learn: 0.1645378	total: 41.4s	remaining: 6m 48s
# 46:	learn: 0.1640714	total: 42.4s	remaining: 6m 48s
# 47:	learn: 0.1634541	total: 43.4s	remaining: 6m 48s
# 48:	learn: 0.1631438	total: 44.4s	remaining: 6m 48s
# 49:	learn: 0.1629231	total: 45.3s	remaining: 6m 47s
# 50:	learn: 0.1625820	total: 46.4s	remaining: 6m 48s
# 51:	learn: 0.1622325	total: 47.1s	remaining: 6m 46s
# 52:	learn: 0.1619277	total: 48.2s	remaining: 6m 46s
# 53:	learn: 0.1617588	total: 49.2s	remaining: 6m 46s
# 54:	learn: 0.1615086	total: 50.2s	remaining: 6m 45s
# 55:	learn: 0.1611241	total: 51.2s	remaining: 6m 46s
# 56:	learn: 0.1609859	total: 52.3s	remaining: 6m 46s
# 57:	learn: 0.1605198	total: 53.1s	remaining: 6m 45s
# 58:	learn: 0.1600767	total: 54s	remaining: 6m 43s
# 59:	learn: 0.1598823	total: 55s	remaining: 6m 43s
# 60:	learn: 0.1597353	total: 55.9s	remaining: 6m 42s
# 61:	learn: 0.1595094	total: 57s	remaining: 6m 42s
# 62:	learn: 0.1588959	total: 58.1s	remaining: 6m 42s
# 63:	learn: 0.1586220	total: 59.2s	remaining: 6m 43s
# 64:	learn: 0.1583594	total: 1m	remaining: 6m 42s
# 65:	learn: 0.1579182	total: 1m 1s	remaining: 6m 41s
# 66:	learn: 0.1576799	total: 1m 1s	remaining: 6m 40s
# 67:	learn: 0.1575192	total: 1m 2s	remaining: 6m 40s
# 68:	learn: 0.1573379	total: 1m 3s	remaining: 6m 38s
# 69:	learn: 0.1566800	total: 1m 5s	remaining: 6m 39s
# 70:	learn: 0.1564617	total: 1m 6s	remaining: 6m 38s
# 71:	learn: 0.1562995	total: 1m 7s	remaining: 6m 38s
# 72:	learn: 0.1558854	total: 1m 8s	remaining: 6m 38s
# 73:	learn: 0.1556514	total: 1m 9s	remaining: 6m 38s
# 74:	learn: 0.1555467	total: 1m 10s	remaining: 6m 39s
# 75:	learn: 0.1553649	total: 1m 11s	remaining: 6m 38s
# 76:	learn: 0.1553170	total: 1m 12s	remaining: 6m 36s
# 77:	learn: 0.1553063	total: 1m 12s	remaining: 6m 31s
# 78:	learn: 0.1551039	total: 1m 13s	remaining: 6m 31s
# 79:	learn: 0.1547803	total: 1m 14s	remaining: 6m 30s
# 80:	learn: 0.1542957	total: 1m 15s	remaining: 6m 29s
# 81:	learn: 0.1541643	total: 1m 16s	remaining: 6m 29s
# 82:	learn: 0.1540809	total: 1m 17s	remaining: 6m 28s
# 83:	learn: 0.1538572	total: 1m 18s	remaining: 6m 27s
# 84:	learn: 0.1536163	total: 1m 19s	remaining: 6m 28s
# 85:	learn: 0.1536064	total: 1m 19s	remaining: 6m 23s
# 86:	learn: 0.1533739	total: 1m 20s	remaining: 6m 23s
# 87:	learn: 0.1528273	total: 1m 21s	remaining: 6m 22s
# 88:	learn: 0.1526043	total: 1m 22s	remaining: 6m 21s
# 89:	learn: 0.1522575	total: 1m 23s	remaining: 6m 20s
# 90:	learn: 0.1518487	total: 1m 24s	remaining: 6m 19s
# 91:	learn: 0.1514682	total: 1m 25s	remaining: 6m 18s
# 92:	learn: 0.1512527	total: 1m 26s	remaining: 6m 18s
# 93:	learn: 0.1508746	total: 1m 27s	remaining: 6m 16s
# 94:	learn: 0.1507005	total: 1m 28s	remaining: 6m 16s
# 95:	learn: 0.1506083	total: 1m 29s	remaining: 6m 15s
# 96:	learn: 0.1503784	total: 1m 30s	remaining: 6m 15s
# 97:	learn: 0.1501707	total: 1m 31s	remaining: 6m 15s
# 98:	learn: 0.1499474	total: 1m 32s	remaining: 6m 14s
# 99:	learn: 0.1493767	total: 1m 33s	remaining: 6m 14s
# 100:	learn: 0.1491919	total: 1m 34s	remaining: 6m 13s
# 101:	learn: 0.1489964	total: 1m 35s	remaining: 6m 12s
# 102:	learn: 0.1484793	total: 1m 36s	remaining: 6m 11s
# 103:	learn: 0.1481572	total: 1m 37s	remaining: 6m 10s
# 104:	learn: 0.1480009	total: 1m 38s	remaining: 6m 9s
# 105:	learn: 0.1479257	total: 1m 39s	remaining: 6m 8s
# 106:	learn: 0.1477003	total: 1m 40s	remaining: 6m 7s
# 107:	learn: 0.1474571	total: 1m 41s	remaining: 6m 7s
# 108:	learn: 0.1471777	total: 1m 42s	remaining: 6m 5s
# 109:	learn: 0.1470630	total: 1m 42s	remaining: 6m 5s
# 110:	learn: 0.1466971	total: 1m 44s	remaining: 6m 4s
# 111:	learn: 0.1464912	total: 1m 44s	remaining: 6m 3s
# 112:	learn: 0.1460083	total: 1m 45s	remaining: 6m 2s
# 113:	learn: 0.1455578	total: 1m 46s	remaining: 6m 1s
# 114:	learn: 0.1451970	total: 1m 47s	remaining: 6m
# 115:	learn: 0.1448453	total: 1m 48s	remaining: 6m
# 116:	learn: 0.1444712	total: 1m 49s	remaining: 5m 59s
# 117:	learn: 0.1442111	total: 1m 51s	remaining: 5m 59s
# 118:	learn: 0.1439683	total: 1m 52s	remaining: 5m 59s
# 119:	learn: 0.1436404	total: 1m 53s	remaining: 5m 58s
# 120:	learn: 0.1432999	total: 1m 54s	remaining: 5m 57s
# 121:	learn: 0.1426701	total: 1m 55s	remaining: 5m 57s
# 122:	learn: 0.1423881	total: 1m 56s	remaining: 5m 56s
# 123:	learn: 0.1420552	total: 1m 57s	remaining: 5m 54s
# 124:	learn: 0.1418783	total: 1m 58s	remaining: 5m 54s
# 125:	learn: 0.1417648	total: 1m 59s	remaining: 5m 53s
# 126:	learn: 0.1415751	total: 2m	remaining: 5m 53s
# 127:	learn: 0.1413004	total: 2m 1s	remaining: 5m 51s
# 128:	learn: 0.1409963	total: 2m 1s	remaining: 5m 50s
# 129:	learn: 0.1406129	total: 2m 2s	remaining: 5m 49s
# 130:	learn: 0.1403165	total: 2m 3s	remaining: 5m 48s
# 131:	learn: 0.1396302	total: 2m 4s	remaining: 5m 47s
# 132:	learn: 0.1394388	total: 2m 5s	remaining: 5m 46s
# 133:	learn: 0.1389586	total: 2m 6s	remaining: 5m 45s
# 134:	learn: 0.1386541	total: 2m 7s	remaining: 5m 43s
# 135:	learn: 0.1380701	total: 2m 8s	remaining: 5m 42s
# 136:	learn: 0.1378292	total: 2m 8s	remaining: 5m 41s
# 137:	learn: 0.1375415	total: 2m 9s	remaining: 5m 40s
# 138:	learn: 0.1372769	total: 2m 10s	remaining: 5m 39s
# 139:	learn: 0.1366419	total: 2m 11s	remaining: 5m 38s
# 140:	learn: 0.1363192	total: 2m 12s	remaining: 5m 37s
# 141:	learn: 0.1358233	total: 2m 13s	remaining: 5m 36s
# 142:	learn: 0.1356442	total: 2m 14s	remaining: 5m 35s
# 143:	learn: 0.1352799	total: 2m 15s	remaining: 5m 34s
# 144:	learn: 0.1349456	total: 2m 16s	remaining: 5m 33s
# 145:	learn: 0.1344639	total: 2m 17s	remaining: 5m 32s
# 146:	learn: 0.1340508	total: 2m 18s	remaining: 5m 31s
# 147:	learn: 0.1338084	total: 2m 19s	remaining: 5m 30s
# 148:	learn: 0.1333959	total: 2m 20s	remaining: 5m 30s
# 149:	learn: 0.1327956	total: 2m 21s	remaining: 5m 29s
# 150:	learn: 0.1323527	total: 2m 22s	remaining: 5m 28s
# 151:	learn: 0.1320759	total: 2m 23s	remaining: 5m 27s
# 152:	learn: 0.1317696	total: 2m 24s	remaining: 5m 26s
# 153:	learn: 0.1316462	total: 2m 24s	remaining: 5m 25s
# 154:	learn: 0.1313058	total: 2m 26s	remaining: 5m 25s
# 155:	learn: 0.1310140	total: 2m 26s	remaining: 5m 23s
# 156:	learn: 0.1306240	total: 2m 27s	remaining: 5m 23s
# 157:	learn: 0.1303635	total: 2m 28s	remaining: 5m 22s
# 158:	learn: 0.1300820	total: 2m 29s	remaining: 5m 20s
# 159:	learn: 0.1298321	total: 2m 30s	remaining: 5m 19s
# 160:	learn: 0.1292162	total: 2m 31s	remaining: 5m 18s
# 161:	learn: 0.1288727	total: 2m 32s	remaining: 5m 18s
# 162:	learn: 0.1285483	total: 2m 33s	remaining: 5m 16s
# 163:	learn: 0.1283428	total: 2m 34s	remaining: 5m 15s
# 164:	learn: 0.1281675	total: 2m 34s	remaining: 5m 14s
# 165:	learn: 0.1278910	total: 2m 35s	remaining: 5m 13s
# 166:	learn: 0.1277002	total: 2m 36s	remaining: 5m 12s
# 167:	learn: 0.1272375	total: 2m 37s	remaining: 5m 11s
# 168:	learn: 0.1270294	total: 2m 38s	remaining: 5m 10s
# 169:	learn: 0.1268416	total: 2m 39s	remaining: 5m 9s
# 170:	learn: 0.1264960	total: 2m 40s	remaining: 5m 9s
# 171:	learn: 0.1262525	total: 2m 41s	remaining: 5m 8s
# 172:	learn: 0.1259197	total: 2m 42s	remaining: 5m 7s
# 173:	learn: 0.1255224	total: 2m 43s	remaining: 5m 6s
# 174:	learn: 0.1252158	total: 2m 44s	remaining: 5m 5s
# 175:	learn: 0.1250189	total: 2m 45s	remaining: 5m 4s
# 176:	learn: 0.1248628	total: 2m 46s	remaining: 5m 2s
# 177:	learn: 0.1246082	total: 2m 46s	remaining: 5m 1s
# 178:	learn: 0.1240891	total: 2m 47s	remaining: 5m
# 179:	learn: 0.1238528	total: 2m 48s	remaining: 4m 59s
# 180:	learn: 0.1237240	total: 2m 49s	remaining: 4m 58s
# 181:	learn: 0.1231667	total: 2m 50s	remaining: 4m 57s
# 182:	learn: 0.1227235	total: 2m 51s	remaining: 4m 56s
# 183:	learn: 0.1225370	total: 2m 52s	remaining: 4m 55s
# 184:	learn: 0.1219109	total: 2m 53s	remaining: 4m 54s
# 185:	learn: 0.1214796	total: 2m 54s	remaining: 4m 53s
# 186:	learn: 0.1211350	total: 2m 55s	remaining: 4m 52s
# 187:	learn: 0.1208355	total: 2m 56s	remaining: 4m 52s
# 188:	learn: 0.1204926	total: 2m 56s	remaining: 4m 51s
# 189:	learn: 0.1202936	total: 2m 57s	remaining: 4m 49s
# 190:	learn: 0.1201105	total: 2m 58s	remaining: 4m 49s
# 191:	learn: 0.1198614	total: 2m 59s	remaining: 4m 48s
# 192:	learn: 0.1196855	total: 3m	remaining: 4m 47s
# 193:	learn: 0.1195542	total: 3m 1s	remaining: 4m 47s
# 194:	learn: 0.1193189	total: 3m 3s	remaining: 4m 46s
# 195:	learn: 0.1190432	total: 3m 4s	remaining: 4m 46s
# 196:	learn: 0.1185868	total: 3m 7s	remaining: 4m 47s
# 197:	learn: 0.1184316	total: 3m 8s	remaining: 4m 46s
# 198:	learn: 0.1179908	total: 3m 9s	remaining: 4m 46s
# 199:	learn: 0.1176942	total: 3m 10s	remaining: 4m 45s
# 200:	learn: 0.1174823	total: 3m 11s	remaining: 4m 44s
# 201:	learn: 0.1171913	total: 3m 11s	remaining: 4m 43s
# 202:	learn: 0.1167756	total: 3m 13s	remaining: 4m 42s
# 203:	learn: 0.1164719	total: 3m 14s	remaining: 4m 41s
# 204:	learn: 0.1158845	total: 3m 15s	remaining: 4m 41s
# 205:	learn: 0.1157840	total: 3m 16s	remaining: 4m 40s
# 206:	learn: 0.1155084	total: 3m 18s	remaining: 4m 40s
# 207:	learn: 0.1153742	total: 3m 19s	remaining: 4m 40s
# 208:	learn: 0.1151187	total: 3m 20s	remaining: 4m 39s
# 209:	learn: 0.1148190	total: 3m 21s	remaining: 4m 38s
# 210:	learn: 0.1146615	total: 3m 22s	remaining: 4m 37s
# 211:	learn: 0.1143352	total: 3m 23s	remaining: 4m 36s
# 212:	learn: 0.1140497	total: 3m 24s	remaining: 4m 36s
# 213:	learn: 0.1136608	total: 3m 25s	remaining: 4m 35s
# 214:	learn: 0.1134867	total: 3m 26s	remaining: 4m 34s
# 215:	learn: 0.1132729	total: 3m 27s	remaining: 4m 33s
# 216:	learn: 0.1129933	total: 3m 28s	remaining: 4m 31s
# 217:	learn: 0.1128282	total: 3m 29s	remaining: 4m 31s
# 218:	learn: 0.1126307	total: 3m 30s	remaining: 4m 30s
# 219:	learn: 0.1123734	total: 3m 31s	remaining: 4m 29s
# 220:	learn: 0.1119278	total: 3m 32s	remaining: 4m 28s
# 221:	learn: 0.1117733	total: 3m 33s	remaining: 4m 27s
# 222:	learn: 0.1113673	total: 3m 34s	remaining: 4m 26s
# 223:	learn: 0.1110475	total: 3m 35s	remaining: 4m 25s
# 224:	learn: 0.1108010	total: 3m 36s	remaining: 4m 24s
# 225:	learn: 0.1106375	total: 3m 37s	remaining: 4m 23s
# 226:	learn: 0.1105439	total: 3m 38s	remaining: 4m 22s
# 227:	learn: 0.1102971	total: 3m 39s	remaining: 4m 21s
# 228:	learn: 0.1099665	total: 3m 40s	remaining: 4m 20s
# 229:	learn: 0.1096737	total: 3m 41s	remaining: 4m 20s
# 230:	learn: 0.1093955	total: 3m 42s	remaining: 4m 19s
# 231:	learn: 0.1092786	total: 3m 44s	remaining: 4m 19s
# 232:	learn: 0.1088923	total: 3m 45s	remaining: 4m 18s
# 233:	learn: 0.1085621	total: 3m 46s	remaining: 4m 17s
# 234:	learn: 0.1083411	total: 3m 48s	remaining: 4m 17s
# 235:	learn: 0.1081597	total: 3m 49s	remaining: 4m 16s
# 236:	learn: 0.1079502	total: 3m 50s	remaining: 4m 15s
# 237:	learn: 0.1077746	total: 3m 51s	remaining: 4m 14s
# 238:	learn: 0.1074885	total: 3m 52s	remaining: 4m 13s
# 239:	learn: 0.1072490	total: 3m 53s	remaining: 4m 12s
# 240:	learn: 0.1069777	total: 3m 54s	remaining: 4m 12s
# 241:	learn: 0.1067019	total: 3m 55s	remaining: 4m 11s
# 242:	learn: 0.1065673	total: 3m 56s	remaining: 4m 10s
# 243:	learn: 0.1062137	total: 3m 58s	remaining: 4m 9s
# 244:	learn: 0.1058922	total: 3m 59s	remaining: 4m 9s
# 245:	learn: 0.1058038	total: 4m	remaining: 4m 8s
# 246:	learn: 0.1054244	total: 4m 1s	remaining: 4m 7s
# 247:	learn: 0.1053435	total: 4m 2s	remaining: 4m 6s
# 248:	learn: 0.1049963	total: 4m 3s	remaining: 4m 5s
# 249:	learn: 0.1047874	total: 4m 5s	remaining: 4m 5s
# 250:	learn: 0.1045852	total: 4m 6s	remaining: 4m 4s
# 251:	learn: 0.1043128	total: 4m 7s	remaining: 4m 3s
# 252:	learn: 0.1041547	total: 4m 8s	remaining: 4m 2s
# 253:	learn: 0.1040929	total: 4m 9s	remaining: 4m 2s
# 254:	learn: 0.1038087	total: 4m 11s	remaining: 4m 1s
# 255:	learn: 0.1035460	total: 4m 12s	remaining: 4m
# 256:	learn: 0.1033665	total: 4m 13s	remaining: 3m 59s
# 257:	learn: 0.1032135	total: 4m 14s	remaining: 3m 58s
# 258:	learn: 0.1030308	total: 4m 15s	remaining: 3m 57s
# 259:	learn: 0.1027877	total: 4m 16s	remaining: 3m 56s
# 260:	learn: 0.1026106	total: 4m 17s	remaining: 3m 55s
# 261:	learn: 0.1024562	total: 4m 18s	remaining: 3m 55s
# 262:	learn: 0.1018669	total: 4m 19s	remaining: 3m 54s
# 263:	learn: 0.1016212	total: 4m 21s	remaining: 3m 53s
# 264:	learn: 0.1015500	total: 4m 22s	remaining: 3m 52s
# 265:	learn: 0.1014320	total: 4m 23s	remaining: 3m 51s
# 266:	learn: 0.1012143	total: 4m 24s	remaining: 3m 50s
# 267:	learn: 0.1009295	total: 4m 25s	remaining: 3m 49s
# 268:	learn: 0.1006979	total: 4m 26s	remaining: 3m 49s
# 269:	learn: 0.1006079	total: 4m 27s	remaining: 3m 48s
# 270:	learn: 0.1004352	total: 4m 28s	remaining: 3m 47s
# 271:	learn: 0.1003076	total: 4m 29s	remaining: 3m 46s
# 272:	learn: 0.1001895	total: 4m 31s	remaining: 3m 45s
# 273:	learn: 0.1001156	total: 4m 32s	remaining: 3m 44s
# 274:	learn: 0.0999118	total: 4m 33s	remaining: 3m 43s
# 275:	learn: 0.0997095	total: 4m 34s	remaining: 3m 42s
# 276:	learn: 0.0994856	total: 4m 35s	remaining: 3m 42s
# 277:	learn: 0.0993503	total: 4m 36s	remaining: 3m 41s
# 278:	learn: 0.0992531	total: 4m 38s	remaining: 3m 40s
# 279:	learn: 0.0988355	total: 4m 39s	remaining: 3m 39s
# 280:	learn: 0.0987480	total: 4m 40s	remaining: 3m 38s
# 281:	learn: 0.0985390	total: 4m 41s	remaining: 3m 37s
# 282:	learn: 0.0983932	total: 4m 42s	remaining: 3m 36s
# 283:	learn: 0.0982779	total: 4m 43s	remaining: 3m 35s
# 284:	learn: 0.0982169	total: 4m 44s	remaining: 3m 34s
# 285:	learn: 0.0980255	total: 4m 45s	remaining: 3m 33s
# 286:	learn: 0.0979281	total: 4m 46s	remaining: 3m 32s
# 287:	learn: 0.0977424	total: 4m 47s	remaining: 3m 31s
# 288:	learn: 0.0974713	total: 4m 48s	remaining: 3m 30s
# 289:	learn: 0.0973074	total: 4m 49s	remaining: 3m 29s
# 290:	learn: 0.0971594	total: 4m 50s	remaining: 3m 28s
# 291:	learn: 0.0970376	total: 4m 51s	remaining: 3m 27s
# 292:	learn: 0.0970091	total: 4m 52s	remaining: 3m 26s
# 293:	learn: 0.0969998	total: 4m 53s	remaining: 3m 25s
# 294:	learn: 0.0967458	total: 4m 54s	remaining: 3m 24s
# 295:	learn: 0.0965393	total: 4m 55s	remaining: 3m 23s
# 296:	learn: 0.0963390	total: 4m 55s	remaining: 3m 22s
# 297:	learn: 0.0962816	total: 4m 57s	remaining: 3m 21s
# 298:	learn: 0.0961034	total: 4m 58s	remaining: 3m 20s
# 299:	learn: 0.0958978	total: 4m 59s	remaining: 3m 19s
# 300:	learn: 0.0957718	total: 5m	remaining: 3m 18s
# 301:	learn: 0.0953690	total: 5m 1s	remaining: 3m 17s
# 302:	learn: 0.0951912	total: 5m 2s	remaining: 3m 16s
# 303:	learn: 0.0951171	total: 5m 2s	remaining: 3m 15s
# 304:	learn: 0.0950088	total: 5m 4s	remaining: 3m 14s
# 305:	learn: 0.0948692	total: 5m 4s	remaining: 3m 13s
# 306:	learn: 0.0946024	total: 5m 6s	remaining: 3m 12s
# 307:	learn: 0.0944200	total: 5m 7s	remaining: 3m 11s
# 308:	learn: 0.0942945	total: 5m 8s	remaining: 3m 10s
# 309:	learn: 0.0941666	total: 5m 9s	remaining: 3m 9s
# 310:	learn: 0.0939054	total: 5m 10s	remaining: 3m 8s
# 311:	learn: 0.0938173	total: 5m 11s	remaining: 3m 7s
# 312:	learn: 0.0936595	total: 5m 12s	remaining: 3m 6s
# 313:	learn: 0.0935067	total: 5m 13s	remaining: 3m 5s
# 314:	learn: 0.0933550	total: 5m 14s	remaining: 3m 4s
# 315:	learn: 0.0932699	total: 5m 15s	remaining: 3m 3s
# 316:	learn: 0.0930932	total: 5m 16s	remaining: 3m 2s
# 317:	learn: 0.0928463	total: 5m 17s	remaining: 3m 1s
# 318:	learn: 0.0927481	total: 5m 17s	remaining: 3m
# 319:	learn: 0.0923208	total: 5m 18s	remaining: 2m 59s
# 320:	learn: 0.0922537	total: 5m 19s	remaining: 2m 58s
# 321:	learn: 0.0921765	total: 5m 20s	remaining: 2m 57s
# 322:	learn: 0.0920876	total: 5m 21s	remaining: 2m 56s
# 323:	learn: 0.0919654	total: 5m 22s	remaining: 2m 55s
# 324:	learn: 0.0914982	total: 5m 23s	remaining: 2m 54s
# 325:	learn: 0.0914001	total: 5m 25s	remaining: 2m 53s
# 326:	learn: 0.0912464	total: 5m 25s	remaining: 2m 52s
# 327:	learn: 0.0909903	total: 5m 26s	remaining: 2m 51s
# 328:	learn: 0.0905150	total: 5m 27s	remaining: 2m 50s
# 329:	learn: 0.0904463	total: 5m 28s	remaining: 2m 49s
# 330:	learn: 0.0900675	total: 5m 29s	remaining: 2m 48s
# 331:	learn: 0.0897115	total: 5m 30s	remaining: 2m 47s
# 332:	learn: 0.0896441	total: 5m 31s	remaining: 2m 46s
# 333:	learn: 0.0894210	total: 5m 32s	remaining: 2m 45s
# 334:	learn: 0.0892966	total: 5m 33s	remaining: 2m 44s
# 335:	learn: 0.0892140	total: 5m 34s	remaining: 2m 43s
# 336:	learn: 0.0888897	total: 5m 35s	remaining: 2m 42s
# 337:	learn: 0.0887106	total: 5m 36s	remaining: 2m 41s
# 338:	learn: 0.0885497	total: 5m 37s	remaining: 2m 40s
# 339:	learn: 0.0883757	total: 5m 38s	remaining: 2m 39s
# 340:	learn: 0.0881366	total: 5m 39s	remaining: 2m 38s
# 341:	learn: 0.0880630	total: 5m 40s	remaining: 2m 37s
# 342:	learn: 0.0878865	total: 5m 41s	remaining: 2m 36s
# 343:	learn: 0.0877901	total: 5m 42s	remaining: 2m 35s
# 344:	learn: 0.0875423	total: 5m 43s	remaining: 2m 34s
# 345:	learn: 0.0874381	total: 5m 43s	remaining: 2m 33s
# 346:	learn: 0.0874151	total: 5m 44s	remaining: 2m 32s
# 347:	learn: 0.0873416	total: 5m 45s	remaining: 2m 31s
# 348:	learn: 0.0871045	total: 5m 46s	remaining: 2m 29s
# 349:	learn: 0.0869408	total: 5m 47s	remaining: 2m 28s
# 350:	learn: 0.0867100	total: 5m 48s	remaining: 2m 27s
# 351:	learn: 0.0865371	total: 5m 49s	remaining: 2m 26s
# 352:	learn: 0.0863174	total: 5m 50s	remaining: 2m 25s
# 353:	learn: 0.0862031	total: 5m 51s	remaining: 2m 24s
# 354:	learn: 0.0859528	total: 5m 52s	remaining: 2m 23s
# 355:	learn: 0.0856354	total: 5m 52s	remaining: 2m 22s
# 356:	learn: 0.0854746	total: 5m 53s	remaining: 2m 21s
# 357:	learn: 0.0854389	total: 5m 54s	remaining: 2m 20s
# 358:	learn: 0.0853559	total: 5m 56s	remaining: 2m 19s
# 359:	learn: 0.0850398	total: 5m 56s	remaining: 2m 18s
# 360:	learn: 0.0849483	total: 5m 57s	remaining: 2m 17s
# 361:	learn: 0.0847945	total: 5m 58s	remaining: 2m 16s
# 362:	learn: 0.0846568	total: 5m 59s	remaining: 2m 15s
# 363:	learn: 0.0845400	total: 6m	remaining: 2m 14s
# 364:	learn: 0.0844995	total: 6m 1s	remaining: 2m 13s
# 365:	learn: 0.0842770	total: 6m 2s	remaining: 2m 12s
# 366:	learn: 0.0841884	total: 6m 3s	remaining: 2m 11s
# 367:	learn: 0.0840349	total: 6m 4s	remaining: 2m 10s
# 368:	learn: 0.0838629	total: 6m 5s	remaining: 2m 9s
# 369:	learn: 0.0837427	total: 6m 6s	remaining: 2m 8s
# 370:	learn: 0.0836505	total: 6m 7s	remaining: 2m 7s
# 371:	learn: 0.0834127	total: 6m 8s	remaining: 2m 6s
# 372:	learn: 0.0832787	total: 6m 9s	remaining: 2m 5s
# 373:	learn: 0.0830900	total: 6m 10s	remaining: 2m 4s
# 374:	learn: 0.0829345	total: 6m 11s	remaining: 2m 3s
# 375:	learn: 0.0828317	total: 6m 12s	remaining: 2m 2s
# 376:	learn: 0.0827691	total: 6m 13s	remaining: 2m 1s
# 377:	learn: 0.0826186	total: 6m 14s	remaining: 2m
# 378:	learn: 0.0824810	total: 6m 15s	remaining: 1m 59s
# 379:	learn: 0.0823845	total: 6m 16s	remaining: 1m 59s
# 380:	learn: 0.0821839	total: 6m 17s	remaining: 1m 58s
# 381:	learn: 0.0820649	total: 6m 18s	remaining: 1m 57s
# 382:	learn: 0.0818881	total: 6m 19s	remaining: 1m 56s
# 383:	learn: 0.0817007	total: 6m 20s	remaining: 1m 55s
# 384:	learn: 0.0814594	total: 6m 21s	remaining: 1m 54s
# 385:	learn: 0.0812040	total: 6m 22s	remaining: 1m 53s
# 386:	learn: 0.0810807	total: 6m 23s	remaining: 1m 51s
# 387:	learn: 0.0807723	total: 6m 24s	remaining: 1m 50s
# 388:	learn: 0.0804993	total: 6m 25s	remaining: 1m 49s
# 389:	learn: 0.0802489	total: 6m 26s	remaining: 1m 48s
# 390:	learn: 0.0800907	total: 6m 27s	remaining: 1m 47s
# 391:	learn: 0.0799667	total: 6m 28s	remaining: 1m 46s
# 392:	learn: 0.0798685	total: 6m 29s	remaining: 1m 45s
# 393:	learn: 0.0797181	total: 6m 30s	remaining: 1m 44s
# 394:	learn: 0.0795454	total: 6m 32s	remaining: 1m 44s
# 395:	learn: 0.0794952	total: 6m 33s	remaining: 1m 43s
# 396:	learn: 0.0792085	total: 6m 34s	remaining: 1m 42s
# 397:	learn: 0.0791099	total: 6m 35s	remaining: 1m 41s
# 398:	learn: 0.0788674	total: 6m 36s	remaining: 1m 40s
# 399:	learn: 0.0786853	total: 6m 37s	remaining: 1m 39s
# 400:	learn: 0.0785542	total: 6m 39s	remaining: 1m 38s
# 401:	learn: 0.0784326	total: 6m 40s	remaining: 1m 37s
# 402:	learn: 0.0782005	total: 6m 42s	remaining: 1m 36s
# 403:	learn: 0.0780015	total: 6m 43s	remaining: 1m 35s
# 404:	learn: 0.0777868	total: 6m 43s	remaining: 1m 34s
# 405:	learn: 0.0777117	total: 6m 44s	remaining: 1m 33s
# 406:	learn: 0.0776422	total: 6m 45s	remaining: 1m 32s
# 407:	learn: 0.0775743	total: 6m 46s	remaining: 1m 31s
# 408:	learn: 0.0775039	total: 6m 47s	remaining: 1m 30s
# 409:	learn: 0.0773611	total: 6m 48s	remaining: 1m 29s
# 410:	learn: 0.0773101	total: 6m 49s	remaining: 1m 28s
# 411:	learn: 0.0770314	total: 6m 50s	remaining: 1m 27s
# 412:	learn: 0.0770095	total: 6m 51s	remaining: 1m 26s
# 413:	learn: 0.0766908	total: 6m 52s	remaining: 1m 25s
# 414:	learn: 0.0766008	total: 6m 54s	remaining: 1m 24s
# 415:	learn: 0.0765425	total: 6m 55s	remaining: 1m 23s
# 416:	learn: 0.0763809	total: 6m 55s	remaining: 1m 22s
# 417:	learn: 0.0761579	total: 6m 56s	remaining: 1m 21s
# 418:	learn: 0.0760538	total: 6m 57s	remaining: 1m 20s
# 419:	learn: 0.0758299	total: 6m 58s	remaining: 1m 19s
# 420:	learn: 0.0757829	total: 6m 59s	remaining: 1m 18s
# 421:	learn: 0.0756260	total: 7m	remaining: 1m 17s
# 422:	learn: 0.0753333	total: 7m 1s	remaining: 1m 16s
# 423:	learn: 0.0751417	total: 7m 2s	remaining: 1m 15s
# 424:	learn: 0.0749087	total: 7m 3s	remaining: 1m 14s
# 425:	learn: 0.0747165	total: 7m 4s	remaining: 1m 13s
# 426:	learn: 0.0746817	total: 7m 5s	remaining: 1m 12s
# 427:	learn: 0.0745420	total: 7m 6s	remaining: 1m 11s
# 428:	learn: 0.0744139	total: 7m 7s	remaining: 1m 10s
# 429:	learn: 0.0743726	total: 7m 8s	remaining: 1m 9s
# 430:	learn: 0.0742467	total: 7m 9s	remaining: 1m 8s
# 431:	learn: 0.0742065	total: 7m 10s	remaining: 1m 7s
# 432:	learn: 0.0737336	total: 7m 11s	remaining: 1m 6s
# 433:	learn: 0.0736646	total: 7m 12s	remaining: 1m 5s
# 434:	learn: 0.0735235	total: 7m 13s	remaining: 1m 4s
# 435:	learn: 0.0734654	total: 7m 14s	remaining: 1m 3s
# 436:	learn: 0.0733740	total: 7m 15s	remaining: 1m 2s
# 437:	learn: 0.0731965	total: 7m 16s	remaining: 1m 1s
# 438:	learn: 0.0731678	total: 7m 17s	remaining: 1m
# 439:	learn: 0.0730525	total: 7m 18s	remaining: 59.8s
# 440:	learn: 0.0729482	total: 7m 19s	remaining: 58.8s
# 441:	learn: 0.0728322	total: 7m 20s	remaining: 57.8s
# 442:	learn: 0.0727990	total: 7m 21s	remaining: 56.8s
# 443:	learn: 0.0726615	total: 7m 22s	remaining: 55.8s
# 444:	learn: 0.0724509	total: 7m 23s	remaining: 54.8s
# 445:	learn: 0.0723502	total: 7m 24s	remaining: 53.8s
# 446:	learn: 0.0722606	total: 7m 25s	remaining: 52.8s
# 447:	learn: 0.0721292	total: 7m 26s	remaining: 51.8s
# 448:	learn: 0.0718993	total: 7m 27s	remaining: 50.8s
# 449:	learn: 0.0717336	total: 7m 27s	remaining: 49.8s
# 450:	learn: 0.0716740	total: 7m 28s	remaining: 48.8s
# 451:	learn: 0.0716189	total: 7m 29s	remaining: 47.8s
# 452:	learn: 0.0714121	total: 7m 30s	remaining: 46.8s
# 453:	learn: 0.0711679	total: 7m 31s	remaining: 45.8s
# 454:	learn: 0.0710568	total: 7m 32s	remaining: 44.8s
# 455:	learn: 0.0708370	total: 7m 33s	remaining: 43.8s
# 456:	learn: 0.0706819	total: 7m 34s	remaining: 42.8s
# 457:	learn: 0.0704960	total: 7m 35s	remaining: 41.8s
# 458:	learn: 0.0704076	total: 7m 36s	remaining: 40.8s
# 459:	learn: 0.0702127	total: 7m 37s	remaining: 39.8s
# 460:	learn: 0.0700262	total: 7m 38s	remaining: 38.8s
# 461:	learn: 0.0699856	total: 7m 39s	remaining: 37.8s
# 462:	learn: 0.0698654	total: 7m 40s	remaining: 36.8s
# 463:	learn: 0.0697692	total: 7m 42s	remaining: 35.9s
# 464:	learn: 0.0695384	total: 7m 43s	remaining: 34.9s
# 465:	learn: 0.0694070	total: 7m 44s	remaining: 33.9s
# 466:	learn: 0.0692703	total: 7m 45s	remaining: 32.9s
# 467:	learn: 0.0692030	total: 7m 46s	remaining: 31.9s
# 468:	learn: 0.0690725	total: 7m 46s	remaining: 30.9s
# 469:	learn: 0.0689900	total: 7m 47s	remaining: 29.9s
# 470:	learn: 0.0687428	total: 7m 48s	remaining: 28.9s
# 471:	learn: 0.0685796	total: 7m 49s	remaining: 27.9s
# 472:	learn: 0.0684039	total: 7m 50s	remaining: 26.9s
# 473:	learn: 0.0683000	total: 7m 51s	remaining: 25.9s
# 474:	learn: 0.0682397	total: 7m 52s	remaining: 24.9s
# 475:	learn: 0.0680422	total: 7m 53s	remaining: 23.9s
# 476:	learn: 0.0677601	total: 7m 54s	remaining: 22.9s
# 477:	learn: 0.0677148	total: 7m 55s	remaining: 21.9s
# 478:	learn: 0.0675272	total: 7m 56s	remaining: 20.9s
# 479:	learn: 0.0674147	total: 7m 57s	remaining: 19.9s
# 480:	learn: 0.0671361	total: 7m 58s	remaining: 18.9s
# 481:	learn: 0.0671116	total: 7m 59s	remaining: 17.9s
# 482:	learn: 0.0669597	total: 8m	remaining: 16.9s
# 483:	learn: 0.0667949	total: 8m 1s	remaining: 15.9s
# 484:	learn: 0.0665780	total: 8m 2s	remaining: 14.9s
# 485:	learn: 0.0664394	total: 8m 3s	remaining: 13.9s
# 486:	learn: 0.0663713	total: 8m 4s	remaining: 12.9s
# 487:	learn: 0.0661708	total: 8m 4s	remaining: 11.9s
# 488:	learn: 0.0660802	total: 8m 5s	remaining: 10.9s
# 489:	learn: 0.0659982	total: 8m 6s	remaining: 9.93s
# 490:	learn: 0.0659300	total: 8m 7s	remaining: 8.94s
# 491:	learn: 0.0657913	total: 8m 8s	remaining: 7.95s
# 492:	learn: 0.0656650	total: 8m 9s	remaining: 6.95s
# 493:	learn: 0.0655836	total: 8m 10s	remaining: 5.96s
# 494:	learn: 0.0653901	total: 8m 11s	remaining: 4.96s
# 495:	learn: 0.0651921	total: 8m 12s	remaining: 3.97s
# 496:	learn: 0.0650620	total: 8m 13s	remaining: 2.98s
# 497:	learn: 0.0648281	total: 8m 14s	remaining: 1.99s
# 498:	learn: 0.0646720	total: 8m 15s	remaining: 992ms
# 499:	learn: 0.0645319	total: 8m 16s	remaining: 0us
# CPU times: user 24min 55s, sys: 11.9 s, total: 25min 7s
# Wall time: 8min 19s

# %%
fi = pd.DataFrame(cb.feature_importances_, index=X_train.columns, columns=['importance'])
fi.sort_values(by='importance', ascending=False)
# Out:
#                             importance
# n_sold_category              11.739362
# avg_transaction_category     10.223615
# item_score                    6.996947
# n_transactions_per_week       5.606859
# price                         5.601787
# Word2Vec_distance_from_avg    5.012876
# item_id                       4.487601
# user_id                       4.347251
# avg_basket_department         4.181837
# sub_commodity_desc            4.078552
# Word2Vec_length               3.966707
# avg_price                     3.739668
# avg_cheque                    3.592322
# avg_interval                  3.250276
# manufacturer                  3.126773
# commodity_desc                3.074240
# curr_size_of_product          2.922628
# department                    2.680300
# quantity_per_week             2.484680
# n_unique_stores               2.470525
# Last5sales                    1.376945
# age_desc                      0.800133
# hh_comp_desc                  0.761436
# marital_status_code           0.747546
# income_desc                   0.691135
# kid_category_desc             0.630464
# household_size_desc           0.568913
# homeowner_desc                0.485450
# brand                         0.353171
# Missing price                 0.000000
# Missing quantity per week     0.000000

# %% [markdown]
# Оценим качество построенной модели с помощью метрики precision@5 на валидационном датасете.

# %%
df_ranker_predict = df_ranker_train.copy()
df_ranker_predict['proba_item_purchase'] = train_preds[:,1]

# %%
N_PREDICT = 100
TOPK_PRECISION = 5

result_eval_ranker = data_val_ranker.groupby(USER_COL)[ITEM_COL].unique().reset_index()
result_eval_ranker.columns=[USER_COL, ACTUAL_COL]
result_eval_ranker['own_rec'] = make_recommendations(result_eval_ranker, 
                                                     recommender.get_own_recommendations, N_PREDICT=N_PREDICT)

sorted(calc_precision(result_eval_ranker, TOPK_PRECISION), key=lambda x: x[1], reverse=True)
# Out:
# [('own_rec', 0.24029411764705885)]

# %%
result_eval_ranker['reranked_own_rec'] = result_eval_ranker[USER_COL].\
                                            apply(lambda user_id: rerank(user_id, df_ranker_predict))
print(*sorted(calc_precision(result_eval_ranker, TOPK_PRECISION), key=lambda x: x[1], reverse=True), sep='\n')
# Out:
# ('reranked_own_rec', 0.2965333333333333)
# ('own_rec', 0.24029411764705885)
# /Users/rk/Documents/Recommender_systems/L8/src/metrics.py:20: RuntimeWarning: invalid value encountered in long_scalars
#   return flags.sum() / len(recommended_list)

# %% [markdown]
# Как видим с помощью модели второго уровня удалось значительно поднять метрики для построенных рекомендаций.

# %% [markdown]
# ### 7. Рекомендации для тестового датасета <a class="anchor" id="final_recommendations"></a>

# %% [markdown]
# Теперь построим предсказания для итогового датасета.

# %%
data_test = pd.read_csv('retail_test1.csv')
data_test.head()
# Out:
#    user_id    basket_id  day  item_id  quantity  sales_value  store_id  \
# 0     1340  41652823310  664   912987         1         8.49       446
# 1      588  41652838477  664  1024426         1         6.29       388
# 2     2070  41652857291  664   995242         5         9.10       311
# 3     1602  41665647035  664   827939         1         7.99       334
# 4     1602  41665647035  664   927712         1         0.59       334
#
#    retail_disc  trans_time  week_no  coupon_disc  coupon_match_disc
# 0          0.0          52       96          0.0                0.0
# 1          0.0           8       96          0.0                0.0
# 2         -0.6          46       96          0.0                0.0
# 3          0.0        1741       96          0.0                0.0
# 4         -0.4        1741       96          0.0                0.0

# %%
df_test_candidates = pd.DataFrame(data_test[USER_COL].unique())
df_test_candidates.columns = [USER_COL]

df_test_candidates['recommendations'] = df_test_candidates[USER_COL].\
                                        apply(lambda user_id: rerank(user_id, df_ranker_predict))

# %%
df_test_candidates.to_csv('recommendations.csv', index=False)
df_test_candidates.head()
# Out:
#    user_id                              recommendations
# 0     1340  [912704, 1037840, 1087755, 6602685, 971646]
# 1      588   [1106523, 907631, 866211, 919534, 1041796]
# 2     2070   [865456, 12810391, 933067, 913210, 916122]
# 3     1602  [1082185, 1070820, 944836, 1104343, 848319]
# 4      447  [899624, 1051211, 5569327, 866488, 1031864]
